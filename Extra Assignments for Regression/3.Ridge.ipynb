# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset.columns
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
dependent=dataset[['charges']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'alpha': [0.0, 0.01, 0.1, 1.0, 10.0],  # L2 regularization strength
    'fit_intercept': [True, False],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr'],
    'max_iter': [None, 1000, 5000]
}

# Create the GridSearchCV object
grid = GridSearchCV(
    estimator=Ridge(),
    param_grid=param_grid,
    scoring='neg_mean_absolute_error',  # or 'neg_mean_squared_error'
    cv=5,
    n_jobs=-1
)

# Fit to the training data
grid.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [0.0, 0.01, 0.1, 1.0, 10.0],
#                          'fit_intercept': [True, False],
#                          'max_iter': [None, 1000, 5000],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr']},
#              scoring='neg_mean_absolute_error')

# %%
y_pred=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,y_pred)

# %%
# Output the best params and score
print("Best Parameters:", grid.best_params_)
print("Best r_score:", r_score)
# Out:
# Best Parameters: {'alpha': 0.0, 'fit_intercept': True, 'max_iter': None, 'solver': 'lsqr'}
# Best r_score: 0.7894790316480158

# %%
import pickle
import numpy as np
filename="3.finalized_model_Ridge_Regressor.sav"
pickle.dump(grid,open(filename,'wb'))
model = pickle.load(open("3.finalized_model_Ridge_Regressor.sav", "rb"))

age = float(input("Age (e.g. 35): "))
bmi = float(input("BMI (e.g. 26.5): "))
children = int(input("Number of children (e.g. 2): "))
sex_male=float(input("Sex male 0 or 1:"))
smoker_yes = int(input("Smoker (1 or 0): "))

    # Prepare input array
user_input = np.array([[age, bmi, children, sex_male, smoker_yes]])

    # Predict using the loaded model
prediction = model.predict(user_input)

    # Show the prediction result
print(f"\nPredicted Result:",prediction)
# Out:
# Age (e.g. 35):  20
# BMI (e.g. 26.5):  27
# Number of children (e.g. 2):  1
# Sex male 0 or 1: 1
# Smoker (1 or 0):  0
# Predicted Result: [[140012.86074489]]
